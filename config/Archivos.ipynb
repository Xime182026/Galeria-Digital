# %% [markdown]
# Método: Get data-GET              🔵  Ususarios
# http://localhost:3000/api/usuarios
#
# Método:Post data-POST             🟢  Crear Usuarios
# http://localhost:3000/api/usuarios
#
# Método: Post data - PUT           🟡   Actualizar usuarios
# URL: http://localhost:3000/api/usuarios/
#
# Método: Post data - DELETE        🔴  Borrar Usuarios
# http://localhost:3000/api/usuarios/
